# %%
import numpy as np

# %%
import pandas as pd

# %%
import pandas as  pd

# %%
df=pd.read_csv("C:\\Users\\devag\\OneDrive\\Desktop\\College placement\\college_student_placement_dataset.csv")

# %%
df.head()
# Out:
#   College_ID   IQ  ...  Projects_Completed  Placement
# 0    CLG0030  107  ...                   4         No
# 1    CLG0061   97  ...                   0         No
# 2    CLG0036  109  ...                   1         No
# 3    CLG0055  122  ...                   1         No
# 4    CLG0004   96  ...                   2         No
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  str
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  str
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  str
# dtypes: float64(2), int64(5), str(3)
# memory usage: 781.4 KB

# %%
df.shape
# Out:
# (10000, 10)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['CGPA'],df['IQ'],c=(df['Placement']=='Yes'))

# %%
x=df.iloc[:,1:9]

# %%
x
# Out:
#        IQ  Prev_Sem_Result  ...  Communication_Skills  Projects_Completed
# 0     107             6.61  ...                     8                   4
# 1      97             5.52  ...                     8                   0
# 2     109             5.36  ...                     1                   1
# 3     122             5.47  ...                     6                   1
# 4      96             7.91  ...                    10                   2
# ...   ...              ...  ...                   ...                 ...
# 9995  119             8.41  ...                     8                   0
# 9996   70             9.25  ...                     7                   2
# 9997   89             6.08  ...                     9                   5
# 9998  107             8.77  ...                     5                   1
# 9999  109             9.41  ...                     5                   5
#
# [10000 rows x 8 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 9995    Yes
# 9996     No
# 9997     No
# 9998     No
# 9999     No
# Name: Placement, Length: 10000, dtype: str

# %%
y.shape
# Out:
# (10000,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#        IQ  Prev_Sem_Result  ...  Communication_Skills  Projects_Completed
# 4448  107             5.42  ...                     1                   3
# 5127   99             5.13  ...                     3                   2
# 5590   91             8.83  ...                    10                   3
# 4295   77             8.31  ...                     6                   5
# 3449   93             6.70  ...                     7                   1
# ...   ...              ...  ...                   ...                 ...
# 6362   92             9.66  ...                     8                   4
# 5890   96             8.41  ...                     4                   5
# 5940   80             9.65  ...                     7                   0
# 9463  103             5.44  ...                     6                   2
# 2701  116             7.01  ...                     9                   2
#
# [8000 rows x 8 columns]

# %%
x_train.shape
# Out:
# (8000, 8)

# %%
num_cols = x_train.select_dtypes(include=['int64','float64']).columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train[num_cols]=scaler.fit_transform(x_train[num_cols])

# %%
x_test[num_cols]=scaler.transform(x_test[num_cols])

# %%
x_train
# Out:
#             IQ  Prev_Sem_Result  ...  Communication_Skills  Projects_Completed
# 4448  0.500255        -1.457712  ...             -1.574418            0.280234
# 5127 -0.033893        -1.657400  ...             -0.885470           -0.302221
# 5590 -0.568042         0.890351  ...              1.525847            0.280234
# 4295 -1.502803         0.532289  ...              0.147952            1.445144
# 3449 -0.434505        -0.576327  ...              0.492425           -0.884677
# ...        ...              ...  ...                   ...                 ...
# 6362 -0.501274         1.461874  ...              0.836899            0.862689
# 5890 -0.234199         0.601147  ...             -0.540996            1.445144
# 5940 -1.302497         1.454988  ...              0.492425           -1.467132
# 9463  0.233181        -1.443940  ...              0.147952           -0.302221
# 2701  1.101173        -0.362867  ...              1.181373           -0.302221
#
# [8000 rows x 8 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14324\1002171229.py in ?()
# ----> 1 model.fit(x_train,y_train)
#
# c:\Users\devag\anaconda3\envs\AIML\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\devag\anaconda3\envs\AIML\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     355         # Validate or convert input data
#     356         if issparse(y):
#     357             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     358
# --> 359         X, y = validate_data(
#     360             self,
#     361             X,
#     362             y,
#
# c:\Users\devag\anaconda3\envs\AIML\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2915             if "estimator" not in check_y_params:
#    2916                 check_y_params = {**default_check_params, **check_y_params}
#    2917             y = check_array(y, input_name="y", **check_y_params)
#    2918         else:
# -> 2919             X, y = check_X_y(X, y, **check_params)
#    2920         out = X, y
#    2921
#    2922     if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\devag\anaconda3\envs\AIML\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1310         raise ValueError(
#    1311             f"{estimator_name} requires y to be passed, but the target y is None"
#    1312         )
#    1313
# -> 1314     X = check_array(
#    1315         X,
#    1316         accept_sparse=accept_sparse,
#    1317         accept_large_sparse=accept_large_sparse,
#
# c:\Users\devag\anaconda3\envs\AIML\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1019                         )
#    1020                     array = xp.astype(array, dtype, copy=False)
#    1021                 else:
#    1022                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1023             except ComplexWarning as complex_warning:
#    1024                 raise ValueError(
#    1025                     "Complex data not supported\n{}\n".format(array)
#    1026                 ) from complex_warning
#
# c:\Users\devag\anaconda3\envs\AIML\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     874         # Use NumPy API to support order
#     875         if copy is True:
#     876             array = numpy.array(array, order=order, dtype=dtype)
#     877         else:
# --> 878             array = numpy.asarray(array, order=order, dtype=dtype)
#     879
#     880         # At this point array is a NumPy ndarray. We convert it to an array
#     881         # container that is consistent with the input's namespace.
#
# c:\Users\devag\anaconda3\envs\AIML\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2035             )
#    2036         values = self._values
#    2037         if copy is None:
#    2038             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2039             arr = np.asarray(values, dtype=dtype)
#    2040         else:
#    2041             arr = np.array(values, dtype=dtype, copy=copy)
#    2042
#
# ValueError: could not convert string to float: 'No'
